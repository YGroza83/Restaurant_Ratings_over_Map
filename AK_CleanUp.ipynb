# %%
# Dependencies and definitions
import random
import pandas as pd
import numpy as np
import requests
import json
import re
import gmaps
import matplotlib.pyplot as plt
from config import gkey
#https://maps.googleapis.com/maps/api/place/nearbysearch/json?
#location=-33.8670522,151.1957362&radius=1500&type=restaurant&keyword=cruise&key=YOUR_API_KEY
# Configure gmaps
gmaps.configure(api_key=gkey)
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# %%
# Setup empty response holder
cities_name = []
State = []
Latitude = []
Longitude = []
Place_ID = []
Price_range = []
Rating = []
Ratings_count = []
restaurant_name = []
country = []

# %%
# assemble url and make API request
# Lower 48 box 25 to 49 -125 to -67

for i in range(5):
    lat = random.uniform(25.000000001, 49.000000001)
    lng = random.uniform(-125.000000001, -67.000000001)
    
    ll_dot = str(lat) +', ' + str(lng)
    
    params = {
    "location": ll_dot,  
    "rankby": "distance",
    "type": "restaurant",
    "key": gkey,
    }
    
    response = requests.get(base_url, params=params).json()
    length_res = (len(response["results"]))
    
    # extract results
    # print(json.dumps(response, indent=4, sort_keys=True))
    try:        
        # Checked in json formatter there are 3-parent attribute         
        
                for j in range(len(response["results"])):
                                            
                    city_state=response["results"][j]["plus_code"]["compound_code"]
                    #print(city_state) 
                        
                    # Using Regular expression(Regex) for slicing city and state
                    x = re.findall("(\w*),", city_state)
                    #print(x)
                    city = x[0]
                    state = x[1]
                    #print(city)
                    #print(state)
                        
                    place_id = response["results"][j]["place_id"]
                    #print(place_id)
                    lat = response["results"][j]["geometry"]["location"]["lat"]
                    #print(lat)
                    lng = response["results"][j]["geometry"]["location"]["lng"]
                    #print(lng)
                    
                    try:
                        price_level = response["results"][j]["price_level"]
                        #print(str(price_level))
                    except:
                        price_level=0.0
                        #print("inside except"+str(price_level))
                        
                    try:
                        rating = response["results"][j]["rating"]
                        #print(str(rating))
                    except:
                        rating=0.0
                        #print("inside except"+str(rating))
                    
                    try:
                        user_ratings_total = response["results"][j]["user_ratings_total"]    
                        #print(str(user_ratings_total))    
                    except:
                        user_ratings_total=0
                        #print("inside except"+str(user_ratings_total)) 
                        
                    try:
                        restaurant = response["results"][j]["name"]    
                        #print(str(user_ratings_total))    
                    except:
                        restaurant="default"
                        #print("inside except"+str(restaurant_name)) 
                    
                        
                        # Empty string check  
                    if("" !=city and "" !=state and "" !=str(place_id) and "" !=str(lat) and "" !=str(lng)  
                       and "" !=str(price_level) and "" !=str(user_ratings_total) and "USA" in str(city_state)
                       and "" !=str(rating) and "" !=str(restaurant)):
                        cities_name.append(city)
                        State.append(state)
                        Place_ID.append(str(place_id))
                        Latitude.append(str(lat))
                        Longitude.append(str(lng))
                        Price_range.append(str(price_level))
                        Rating.append(str(rating))
                        Ratings_count.append(str(user_ratings_total))
                        restaurant_name.append(str(restaurant))
                        #print("inside")

                        
                    
                        
    except(KeyError, IndexError):
        print("Data not found. Skipping...")
        continue
    
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a data frame using data retrieved
food_ratings_df = pd.DataFrame({ 
                "City" : cities_name,
                "State" : State,
                "Country" : "USA",
                "Restaurant_Name" :restaurant_name,
                "Place_ID" : Place_ID,
                "Price_Range" : Price_range,
                "Rating" : Rating,
                "Ratings_Count" : Ratings_count,
                "Lat" : Latitude,
                "Lng" : Longitude
})

#food_ratings_df.dropna(inplace=True)
food_ratings_df.head(30)
#food_ratings_df.count(60)
# Out:
#        City State Country                    Restaurant_Name  \
# 0  Petoskey    MI     USA  The Party Shoppe on Pickerel Lake
# 1     River    MI     USA      Michael's Tavern & Steakhouse
# 2     River    MI     USA                            Vivio's
#
#                       Place_ID Price_Range Rating Ratings_Count         Lat  \
# 0  ChIJZciCNXV8NU0R2whJDsVyJfI         0.0    4.8             6  45.3862668
# 1  ChIJ__-PISxxNU0RJujdXuLoW0I         0.0    4.6           176  45.3946861
# 2  ChIJ57JXZyxxNU0RGdCLimBalJ8           2    4.4           581  45.3964461
#
#            Lng
# 0  -84.7692799
# 1  -84.6286954
# 2  -84.6287071

# %%
# Export the city data into a .csv.
#food_ratings_df.to_csv("resturent_output_final.csv", index = False)

# %%
food_ratings_df.count()
# Out:
# City               61
# State              61
# Country            61
# Restaurant_Name    61
# Place_ID           61
# Price_Range        61
# Rating             61
# Ratings_Count      61
# Lat                61
# Lng                61
# dtype: int64

# %% [markdown]
# # Graphs

# %%
# Load Csv file
data = pd.read_csv('resturent_output_final.csv')
data.dropna(inplace = True) 
data.head(40)
# Out:
#             City State                              Restaurant_Name  \
# 0        Venetia    PA                             Lyn Palace resto
# 1           Park    PA                      Luciano's Pizza & Pasta
# 2       Township    PA                                    Honeymoon
# 3           Park    PA                                       Subway
# 4       Township    PA                          Castle Tavern South
# 5           Park    PA                                     7-Eleven
# 6           Park    PA                             Trolley Stop Inn
# 7       Township    PA                        Hot Box Pizza & Wings
# 8       Township    PA                                Ya Ya's Pizza
# 9    Finleyville    PA                       Beach House Restaurant
# 10   Finleyville    PA                                     Tiki Bar
# 11      Township    PA                             Blue Line Grille
# 12      Township    PA                             Blue Line Grille
# 13      Township    PA                                     My Place
# 14      McMurray    PA                                       Subway
# 15      McMurray    PA                                  Parea Gyros
# 16      McMurray    PA                      Lorenzo's Pub and Pizza
# 17      McMurray    PA                                    Pizza Hut
# 18    Canonsburg    PA                                China Express
# 19      McMurray    PA                                    Starbucks
# 20        Harrah    WA                  Ms. Shawna's Farmhouse Cafe
# 21      Brooklin    ME               The Lookout Wedding & Catering
# 22      Brooklin    ME                             The Brooklin Inn
# 23       Raphaël    QC                        Casse-croute d'Amours
# 25      Montreal    QC                        District 40 Resto Bar
# 32      Montreal    QC                            La Bella Italiana
# 44        Tieton    WA                      Fernando's Mexican Food
# 45        Tieton    WA                                    DON MATEO
# 46       Cowiche    WA                             Cocina Zacatecas
# 47      McGregor    MN                        Prairie River Retreat
# 48       English    IA                                 Butch's Cafe
# 49       English    IA                                 EV Malt Shop
# 50       English    IA                                      Casey's
# 51  Labadieville    LA                      Cajun Cafe On The Bayou
# 52  Labadieville    LA                     Vinnie's Sandwich Shoppe
# 53    Washington    NC           La Mesa Mexican Restaurant and Bar
# 54    Washington    NC  Taqueria El Gallito (El Gallito Restaurant)
# 55    Washington    NC                                    La Ribera
# 56    Washington    NC                             Pizza Inn Buffet
# 57    Washington    NC                                       Arby's
#
#                        Place_ID  Price_Range  Rating  Ratings_Count  \
# 0   ChIJ5dJ-c_b_NIgRKlRis7WfXR0          0.0     0.0            0.0
# 1   ChIJiZQtdCX5NIgRbdVyyR8tryM          2.0     4.0          255.0
# 2   ChIJn-p6j0n5NIgRi2P7lP-eK3A          0.0     4.3          118.0
# 3   ChIJTdDj1kn5NIgRqEkTP9j_e0k          1.0     4.3           80.0
# 4   ChIJE816nkn5NIgRBggTcKYb2nQ          1.0     4.5          343.0
# 5   ChIJQe-WKUj5NIgRMTHszePOI20          1.0     3.6           11.0
# 6   ChIJJwykOkj5NIgRhEASiE-O2QY          1.0     4.4          551.0
# 7   ChIJJQNR8Uz5NIgR-wmLhBUE5uE          1.0     3.7           75.0
# 8   ChIJLcvi4kz5NIgR_Ovd8SOGMqo          2.0     4.1          139.0
# 9   ChIJmfdaJrv-NIgRnIKBTBv_jPg          1.0     4.5          211.0
# 10  ChIJrYpQJrv-NIgRPrSLTbnnyBU          0.0     4.6          140.0
# 11  ChIJN2LQUFP5NIgRexI-iu62_GY          0.0     4.2           26.0
# 12  ChIJtYnSC035NIgRF8LmFe4ikzI          2.0     4.1          266.0
# 13  ChIJ3VVVDU35NIgRh3vfwDDve5w          1.0     4.1           42.0
# 14  ChIJdT6qkEX_NIgRTzBsWTVeUUc          1.0     3.9           40.0
# 15  ChIJH8qlJh7_NIgRWv8YavzUpDM          1.0     4.4           94.0
# 16  ChIJJdKGnEX_NIgRliHr7hRafQk          0.0     4.6          129.0
# 17  ChIJpQFi90__NIgRkh_P73OyYyA          1.0     3.6           62.0
# 18  ChIJx8oO9k__NIgRpcP_s3OliA4          2.0     4.3           71.0
# 19  ChIJZWnOZEX_NIgRr5yCyziqrZc          2.0     4.3          154.0
# 20  ChIJ6z8r2OWCl1QRqubS9neoJfM          0.0     4.3           18.0
# 21  ChIJEV7_X7WbrkwRp91xhuecvd0          0.0     0.0            0.0
# 22  ChIJ5d5l-RibrkwRPrmGTaz9PTs          0.0     4.3           58.0
# 23  ChIJdZy4iYDeuEwRULV6P48anZ4          2.0     4.1          144.0
# 25  ChIJO6bXSfMeyUwReQdt6Pd057U          0.0     0.0            0.0
# 32  ChIJHRrbmo0eyUwRz_Xc0ecdSOI          2.0     4.6          675.0
# 44  ChIJIWXDXJpgl1QReDnevKCDIH8          1.0     4.6           53.0
# 45  ChIJQwFRXppgl1QRQ6TIjbNcaNg          0.0     4.7          116.0
# 46  ChIJ4Xyb0BFhl1QRlawxCIfhMu4          0.0     5.0            2.0
# 47  ChIJ-_ZDnSKrsVIRTKXM43yjO34          2.0     4.4           68.0
# 48  ChIJO1rRfUXB5YcROIlXDOFVlt0          0.0     4.8            6.0
# 49  ChIJk6rVXkXB5YcR7CWfdq76O3c          1.0     4.6          163.0
# 50  ChIJP9Knn1rB5YcRwoJVZMd3HvM          1.0     4.4           28.0
# 51  ChIJEdtFcJpBIYYR-1KQaFtdKM0          0.0     4.5           19.0
# 52  ChIJR1_72xFBIYYRgq3NSq-lZX8          0.0     4.4           35.0
# 53  ChIJd9WiyLkjr4kRfWRRTnCSpmo          0.0     4.6          102.0
# 54  ChIJsyWAfoAir4kRYIkM5U4Feo0          0.0     4.6           64.0
# 55  ChIJKTt5-oAir4kRMxEMKpRK658          1.0     4.3          285.0
# 56  ChIJVSpQ_4EYr4kRG6drak0XZe8          1.0     3.9          577.0
# 57  ChIJF7XgdH8ir4kRGr6liCaU2DE          1.0     4.2          493.0
#
#           Lat         Lng
# 0   40.286502  -80.061851
# 1   40.297428  -80.045019
# 2   40.290415  -80.028820
# 3   40.292478  -80.031048
# 4   40.291119  -80.028517
# 5   40.293707  -80.031034
# 6   40.293428  -80.030307
# 7   40.287069  -80.023727
# 8   40.286515  -80.022794
# 9   40.271431  -80.020911
# 10  40.270872  -80.020805
# 11  40.286770  -80.021545
# 12  40.286765  -80.021538
# 13  40.286572  -80.021416
# 14  40.278960  -80.082221
# 15  40.278425  -80.083250
# 16  40.279789  -80.083397
# 17  40.280747  -80.083773
# 18  40.279490  -80.084248
# 19  40.279571  -80.084546
# 20  46.403836 -120.543705
# 21  44.263072  -68.520134
# 22  44.265570  -68.571038
# 23  46.799212  -70.755122
# 25  45.589048  -73.582284
# 32  45.585728  -73.579658
# 44  46.704790 -120.755576
# 45  46.704728 -120.754994
# 46  46.670653 -120.710334
# 47  46.757259  -93.249464
# 48  41.514215  -92.076311
# 49  41.512954  -92.076575
# 50  41.511235  -92.076925
# 51  29.837677  -90.951988
# 52  29.835483  -90.949591
# 53  35.561042  -77.055841
# 54  35.560186  -77.056043
# 55  35.559684  -77.056122
# 56  35.563960  -77.061763
# 57  35.562042  -77.059760

# %%
# Store latitude and longitude in locations
locations = data[["Lat","Lng"]]

# Fill NaN values and convert to int
rating = data["Rating"]

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=True, max_intensity=10,
                                     point_radius=10)


# Add layer
fig.add_layer(heat_layer)


# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
